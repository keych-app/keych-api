# %%
import os,shutil
import shlex
import subprocess
import json
from jsonschema_to_openapi.convert import convert

# dalla cartella root: 
# sudo rm -rf ./GeneratedClient

# %%
# Function to load JSON schema from a file
def load_json_schema(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

def clear_folder(folder_path):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))
            
# Function to convert JSON Schema types to OpenAPI (handling nullable types)
def convert_types(schema):
    if 'type' in schema and isinstance(schema['type'], list):
        # Check if 'null' is one of the types (indicating a nullable type)
        if 'null' in schema['type']:
            schema['nullable'] = True
            # Remove 'null' from the type list
            schema['type'] = [t for t in schema['type'] if t != 'null']
            # If there's only one type left, use it directly instead of a list
            if len(schema['type']) == 1:
                schema['type'] = schema['type'][0]
                
def delete_with_sudo(path):
    if os.path.exists(path):
        command = f"sudo rm -rf {shlex.quote(path)}"
        subprocess.run(command, shell=True, check=True)

# Function to update $ref paths for OpenAPI
def update_refs(schema):
    if isinstance(schema, dict):
        # Iterate over a list of items to avoid runtime error
        for key, value in list(schema.items()):
            if key == '$ref':
                # Update $ref to point to the components/schemas location
                schema[key] = value.replace('#/definitions/', '#/components/schemas/')
            else:
                update_refs(value)
    elif isinstance(schema, list):
        for item in schema:
            update_refs(item)

# Function to handle nullable types
def handle_nullable_types(schema):
    if isinstance(schema, dict):
        for key, value in list(schema.items()):
            if key == 'type' and isinstance(value, list) and 'null' in value:
                schema['nullable'] = True
                schema['type'] = [t for t in value if t != 'null'][0]  # Take the first non-null type
            else:
                handle_nullable_types(value)
    elif isinstance(schema, list):
        for item in schema:
            handle_nullable_types(item)

def process_schema(schema):
    # Apply conversions recursively for all schemas
    if isinstance(schema, dict):
        for key, value in schema.items():
            process_schema(value)
        convert_types(schema)
        update_refs(schema)
    elif isinstance(schema, list):
        for item in schema:
            process_schema(item)
            

# Function to create the requestBody schema
def create_request_body_schema(schema):
    if 'oneOf' in schema:
        return {"oneOf": schema["oneOf"]}
    else:
        # Assuming a single message structure, adjust as needed
        return {
            "type": "object",
            "properties": schema.get("properties", {}),
            "required": schema.get("required", [])
        }

# %% [raw]
# # Function to convert JSON Schema to OpenAPI Schema
# def convert_to_openapi_schema(json_schema):
#     openapi_schema = {
#         "openapi": "3.0.0",
#         "info": {
#             "title": "Your API Title",
#             "version": "1.0.0"
#         },
#         "paths": {},  # Paths are required, add your endpoint definitions here
#         "components": {
#             "schemas": {}
#         }
#     }
#
#     # Copy definitions to components/schemas
#     if "definitions" in json_schema:
#         openapi_schema["components"]["schemas"].update(json_schema["definitions"])
#
#      # Adapt oneOf polymorphism
#     if "oneOf" in json_schema:
#         # Ensure each schema in 'oneOf' has a defined 'type'
#         oneOf_schemas = []
#         for schema in json_schema["oneOf"]:
#             if 'type' not in schema:
#                 schema['type'] = 'object'  # Assuming 'object', adjust as necessary
#             oneOf_schemas.append(schema)
#
#         openapi_schema["components"]["schemas"]["PolymorphicType"] = {
#             "oneOf": oneOf_schemas
#         }
#
#     return openapi_schema

# %%
# Create theoutput directory for the generated client
output_dir = os.path.join(os.getcwd(), 'GeneratedClient')
os.makedirs(output_dir, exist_ok=False)  # False is needed because of Docker!
clear_folder(output_dir)

# Create the directory containing OpenAPI specifications
openapi_dir = os.path.join(os.getcwd(), 'OpenAPI')
os.makedirs(openapi_dir, exist_ok=True)
clear_folder(openapi_dir)

# %%
# Iterate over subdirectories in the current directory
for subdir in next(os.walk('.'))[1]:
    schema_dir = os.path.join(subdir, 'schema')
    output_openapi_dir = os.path.join(openapi_dir,os.path.basename(os.path.normpath(subdir)))
    # Check if 'schema' directory exists in the subdirectory
    if os.path.isdir(schema_dir):
        for file in os.listdir(schema_dir):
            # Process only files ending with '_msg.json'
            if file.endswith('_msg.json'):
                file_path = os.path.join(schema_dir, file)
                json_schema = load_json_schema(file_path)
                print(f"file being processed {file_path}")
                # Convert the JSON Schema to an OpenAPI Schema
                # Convert the JSON Schema to an OpenAPI Schema
                openapi_schema = {
                    "openapi": "3.0.0",
                    "info": {
                        "title": "Your API Title",
                        "version": "1.0.0"
                    },
                    "paths": {
                        "/execute-message": {  # Example endpoint
                            "post": {
                                "summary": "Execute a message",
                                "description": "Accepts different types of messages based on the provided schema",
                                "requestBody": {
                                    "required": True,
                                    "content": {
                                        "application/json": {
                                            "schema": create_request_body_schema(json_schema)
                                        }
                                    }
                                },
                                "responses": {
                                    "200": {
                                        "description": "Message processed successfully"
                                        # Define the response schema if applicable
                                    },
                                    "default": {
                                        "description": "An error occurred"
                                    }
                                }
                            }
                        }
                    },
                    "components": {
                        "schemas": json_schema["definitions"] if "definitions" in json_schema else {}
                    }
                }
                update_refs(openapi_schema)
                handle_nullable_types(openapi_schema)

                # Convert JSON Schema to OpenAPI Schema
                #openapi_schema = convert(json_schema)
                #openapi_schema= convert_to_openapi_schema(json_schema)

                # Save the OpenAPI schema to a new file
                output_file_path = os.path.join(output_openapi_dir,file.replace('_msg.json', '_openapi.json'))
                if not os.path.exists(output_openapi_dir):
                    try:
                        os.makedirs(output_openapi_dir)
                    except Exception as e:
                        print(e)
                        raise
                with open(output_file_path, 'w') as outfile:
                    json.dump(openapi_schema, outfile, indent=4)
# Out:
# file being processed minter/schema/query_msg.json
# file being processed minter/schema/instantiate_msg.json
# file being processed minter/schema/execute_msg.json
# file being processed minter-factory/schema/query_msg.json
# file being processed minter-factory/schema/instantiate_msg.json
# file being processed minter-factory/schema/execute_msg.json
# file being processed snip721-collection/schema/query_msg.json
# file being processed snip721-collection/schema/instantiate_msg.json
# file being processed snip721-collection/schema/execute_msg.json

# %%
# Iterate over all OpenAPI specification files in the openapi_dir

for dir in os.listdir(openapi_dir):
    input_dir = os.path.join(openapi_dir,dir)
    if os.path.isdir(input_dir):
        for filename in os.listdir(input_dir):
            print(f"{dir}/{filename}")
            if filename.endswith('.yaml') or filename.endswith('.json'):
                openapi_file_path = os.path.join(input_dir, filename)
                output_client_dir = os.path.join(output_dir, dir, filename.split('.')[0])
                # Docker command to run OpenAPI Generator
                cmd = [
                    'docker', 'run', '--rm',
                    '-v', f'{os.getcwd()}:/local',
                    'openapitools/openapi-generator-cli', 'generate',
                    '-i', f'/local/{os.path.relpath(openapi_file_path,os.getcwd())}',
                    '-g', 'javascript',
                    '-o', f'/local/{os.path.relpath(output_client_dir,os.getcwd())}'
                ]

                # Run the command
                subprocess.run(cmd, check=True)

                print(f"Generated JavaScript client for {filename} in {output_client_dir}")
# Out:
# minter/execute_openapi.json
# [main] INFO  o.o.codegen.DefaultGenerator - Generating with dryRun=false
# [main] INFO  o.o.c.ignore.CodegenIgnoreProcessor - Output directory (/local/GeneratedClient/minter/execute_openapi) does not exist, or is inaccessible. No file (.openapi-generator-ignore) will be evaluated.
# [main] INFO  o.o.codegen.DefaultGenerator - OpenAPI Generator: javascript (client)
# [main] INFO  o.o.codegen.DefaultGenerator - Generator 'javascript' is considered stable.
# [main] INFO  o.o.c.l.JavascriptClientCodegen - Environment variable JS_POST_PROCESS_FILE not defined so the JS code may not be properly formatted. To define it, try 'export JS_POST_PROCESS_FILE="/usr/local/bin/js-beautify -r -f"' (Linux/Mac)
# [main] INFO  o.o.c.l.JavascriptClientCodegen - NOTE: To enable file post-processing, 'enablePostProcessFile' must be set to `true` (--enable-post-process-file for CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_deactivate_collection. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_deactivate_collection=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_deactivate_collection=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_1_new_offspring_contract. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_1_new_offspring_contract=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_1_new_offspring_contract=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_2_create_viewing_key. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_2_create_viewing_key=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_2_create_viewing_key=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_3_set_viewing_key. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_3_set_viewing_key=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_3_set_viewing_key=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_3. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_3=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_3=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_4_set_status. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_4_set_status=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_4_set_status=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_4. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_4=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_4=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_5_revoke_permit. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_5_revoke_permit=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_5_revoke_permit=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_5. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_5=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_5=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/CodeInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/CodeInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/CodeInfo.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequest.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequest.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequest.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf1.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf1.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf1.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf1NewOffspringContract.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf1NewOffspringContract.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf1NewOffspringContract.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf2.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf2.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf2.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf2CreateViewingKey.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf2CreateViewingKey.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf2CreateViewingKey.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf3.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf3.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf3.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf3SetViewingKey.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf3SetViewingKey.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf3SetViewingKey.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf4.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf4.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf4.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf4SetStatus.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf4SetStatus.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf4SetStatus.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf5.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf5.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf5.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOf5RevokePermit.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOf5RevokePermit.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOf5RevokePermit.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/model/ExecuteMessagePostRequestOneOfDeactivateCollection.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/model/ExecuteMessagePostRequestOneOfDeactivateCollection.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/ExecuteMessagePostRequestOneOfDeactivateCollection.md
# [main] WARN  o.o.codegen.DefaultCodegen - Empty operationId found for path: post /execute-message. Renamed to auto-generated operationId: execute_messagePost
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/api/DefaultApi.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/test/api/DefaultApi.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/docs/DefaultApi.md
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/package.json
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/git_push.sh
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/README.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/mocha.opts
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/.travis.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/.gitignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/index.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/src/ApiClient.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/.babelrc
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/.openapi-generator-ignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/.openapi-generator/VERSION
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/execute_openapi/.openapi-generator/FILES
# ################################################################################
# # Thanks for using OpenAPI Generator.                                          #
# # Please consider donation to help us maintain this project 🙏                 #
# # https://opencollective.com/openapi_generator/donate                          #
# ################################################################################
# Generated JavaScript client for execute_openapi.json in /home/rico/Repos/json-to-openapi/GeneratedClient/minter/execute_openapi
# minter/query_openapi.json
# [main] INFO  o.o.codegen.DefaultGenerator - Generating with dryRun=false
# [main] INFO  o.o.c.ignore.CodegenIgnoreProcessor - Output directory (/local/GeneratedClient/minter/query_openapi) does not exist, or is inaccessible. No file (.openapi-generator-ignore) will be evaluated.
# [main] INFO  o.o.codegen.DefaultGenerator - OpenAPI Generator: javascript (client)
# [main] INFO  o.o.codegen.DefaultGenerator - Generator 'javascript' is considered stable.
# [main] INFO  o.o.c.l.JavascriptClientCodegen - Environment variable JS_POST_PROCESS_FILE not defined so the JS code may not be properly formatted. To define it, try 'export JS_POST_PROCESS_FILE="/usr/local/bin/js-beautify -r -f"' (Linux/Mac)
# [main] INFO  o.o.c.l.JavascriptClientCodegen - NOTE: To enable file post-processing, 'enablePostProcessFile' must be set to `true` (--enable-post-process-file for CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_list_my_collections. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_list_my_collections=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_list_my_collections=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_1_list_active_collections. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_1_list_active_collections=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_1_list_active_collections=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_3_is_key_valid. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_3_is_key_valid=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_3_is_key_valid=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_3. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_3=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_3=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_4_is_permit_valid. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_4_is_permit_valid=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_4_is_permit_valid=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_4. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_4=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_4=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequest.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequest.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequest.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf1.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf1.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf1.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf1ListActiveCollections.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf1ListActiveCollections.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf1ListActiveCollections.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf2.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf2.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf2.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf3.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf3.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf3.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf3IsKeyValid.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf3IsKeyValid.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf3IsKeyValid.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf4.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf4.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf4.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOf4IsPermitValid.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOf4IsPermitValid.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOf4IsPermitValid.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/ExecuteMessagePostRequestOneOfListMyCollections.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/ExecuteMessagePostRequestOneOfListMyCollections.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/ExecuteMessagePostRequestOneOfListMyCollections.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/FilterTypes.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/FilterTypes.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/FilterTypes.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/PermitForTokenPermissions.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/PermitForTokenPermissions.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/PermitForTokenPermissions.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/PermitParamsForTokenPermissions.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/PermitParamsForTokenPermissions.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/PermitParamsForTokenPermissions.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/PermitSignature.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/PermitSignature.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/PermitSignature.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/PubKey.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/PubKey.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/PubKey.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/model/TokenPermissions.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/model/TokenPermissions.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/TokenPermissions.md
# [main] WARN  o.o.codegen.DefaultCodegen - Empty operationId found for path: post /execute-message. Renamed to auto-generated operationId: execute_messagePost
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/api/DefaultApi.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/test/api/DefaultApi.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/docs/DefaultApi.md
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/package.json
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/git_push.sh
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/README.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/mocha.opts
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/.travis.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/.gitignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/index.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/src/ApiClient.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/.babelrc
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/.openapi-generator-ignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/.openapi-generator/VERSION
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/query_openapi/.openapi-generator/FILES
# ################################################################################
# # Thanks for using OpenAPI Generator.                                          #
# # Please consider donation to help us maintain this project 🙏                 #
# # https://opencollective.com/openapi_generator/donate                          #
# ################################################################################
# Generated JavaScript client for query_openapi.json in /home/rico/Repos/json-to-openapi/GeneratedClient/minter/query_openapi
# minter/instantiate_openapi.json
# [main] INFO  o.o.codegen.DefaultGenerator - Generating with dryRun=false
# [main] INFO  o.o.c.ignore.CodegenIgnoreProcessor - Output directory (/local/GeneratedClient/minter/instantiate_openapi) does not exist, or is inaccessible. No file (.openapi-generator-ignore) will be evaluated.
# [main] INFO  o.o.codegen.DefaultGenerator - OpenAPI Generator: javascript (client)
# [main] INFO  o.o.codegen.DefaultGenerator - Generator 'javascript' is considered stable.
# [main] INFO  o.o.c.l.JavascriptClientCodegen - Environment variable JS_POST_PROCESS_FILE not defined so the JS code may not be properly formatted. To define it, try 'export JS_POST_PROCESS_FILE="/usr/local/bin/js-beautify -r -f"' (Linux/Mac)
# [main] INFO  o.o.c.l.JavascriptClientCodegen - NOTE: To enable file post-processing, 'enablePostProcessFile' must be set to `true` (--enable-post-process-file for CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as LicenseTypeInfo_price_inner. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings LicenseTypeInfo_price_inner=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings LicenseTypeInfo_price_inner=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/model/CodeInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/test/model/CodeInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/docs/CodeInfo.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/model/ExecuteMessagePostRequest.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/test/model/ExecuteMessagePostRequest.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/docs/ExecuteMessagePostRequest.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/model/LicenseTypeInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/test/model/LicenseTypeInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/docs/LicenseTypeInfo.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/model/LicenseTypeInfoPriceInner.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/test/model/LicenseTypeInfoPriceInner.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/docs/LicenseTypeInfoPriceInner.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/model/ProductInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/test/model/ProductInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/docs/ProductInfo.md
# [main] WARN  o.o.codegen.DefaultCodegen - Empty operationId found for path: post /execute-message. Renamed to auto-generated operationId: execute_messagePost
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/api/DefaultApi.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/test/api/DefaultApi.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/docs/DefaultApi.md
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/package.json
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/git_push.sh
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/README.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/mocha.opts
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/.travis.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/.gitignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/index.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/src/ApiClient.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/.babelrc
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/.openapi-generator-ignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/.openapi-generator/VERSION
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/minter/instantiate_openapi/.openapi-generator/FILES
# ################################################################################
# # Thanks for using OpenAPI Generator.                                          #
# # Please consider donation to help us maintain this project 🙏                 #
# # https://opencollective.com/openapi_generator/donate                          #
# ################################################################################
# Generated JavaScript client for instantiate_openapi.json in /home/rico/Repos/json-to-openapi/GeneratedClient/minter/instantiate_openapi
# minter-factory/execute_openapi.json
# [main] INFO  o.o.codegen.DefaultGenerator - Generating with dryRun=false
# [main] INFO  o.o.c.ignore.CodegenIgnoreProcessor - Output directory (/local/GeneratedClient/minter-factory/execute_openapi) does not exist, or is inaccessible. No file (.openapi-generator-ignore) will be evaluated.
# [main] INFO  o.o.codegen.DefaultGenerator - OpenAPI Generator: javascript (client)
# [main] INFO  o.o.codegen.DefaultGenerator - Generator 'javascript' is considered stable.
# [main] INFO  o.o.c.l.JavascriptClientCodegen - Environment variable JS_POST_PROCESS_FILE not defined so the JS code may not be properly formatted. To define it, try 'export JS_POST_PROCESS_FILE="/usr/local/bin/js-beautify -r -f"' (Linux/Mac)
# [main] INFO  o.o.c.l.JavascriptClientCodegen - NOTE: To enable file post-processing, 'enablePostProcessFile' must be set to `true` (--enable-post-process-file for CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_create_minter. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_create_minter=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_create_minter=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_1_deactivate_minter. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_1_deactivate_minter=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_1_deactivate_minter=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_1. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_1=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_1=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_2_new_minter_contract. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_2_new_minter_contract=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_2_new_minter_contract=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_2. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_2=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_2=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_3_new_collection_contract. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_3_new_collection_contract=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_3_new_collection_contract=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_3. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_3=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_3=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_4_create_viewing_key. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_4_create_viewing_key=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_4_create_viewing_key=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_4. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_4=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_4=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_5_set_viewing_key. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_5_set_viewing_key=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_5_set_viewing_key=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_5. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_5=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_5=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_6_set_status. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_6_set_status=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_6_set_status=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_6. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_6=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_6=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_7_revoke_permit. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_7_revoke_permit=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_7_revoke_permit=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request_oneOf_7. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request_oneOf_7=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request_oneOf_7=NewModel,ModelA=NewModelA in CLI).
# ...
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf4.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf4.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf4.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf5.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf5.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf5.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf6.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf6.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf6.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf6InventoryApprovals.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf6InventoryApprovals.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf6InventoryApprovals.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf7.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf7.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf7.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf7VerifyTransferApproval.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf7VerifyTransferApproval.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf7VerifyTransferApproval.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf8.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf8.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf8.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf8TransactionHistory.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf8TransactionHistory.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf8TransactionHistory.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOf9.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOf9.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOf9.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/QueryWithPermitOneOfRoyaltyInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/QueryWithPermitOneOfRoyaltyInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/QueryWithPermitOneOfRoyaltyInfo.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/TokenPermissions.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/TokenPermissions.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/TokenPermissions.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/model/ViewerInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/model/ViewerInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/ViewerInfo.md
# [main] WARN  o.o.codegen.DefaultCodegen - Empty operationId found for path: post /execute-message. Renamed to auto-generated operationId: execute_messagePost
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/api/DefaultApi.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/test/api/DefaultApi.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/docs/DefaultApi.md
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/package.json
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/git_push.sh
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/README.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/mocha.opts
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/.travis.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/.gitignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/index.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/src/ApiClient.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/.babelrc
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/.openapi-generator-ignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/.openapi-generator/VERSION
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/query_openapi/.openapi-generator/FILES
# ################################################################################
# # Thanks for using OpenAPI Generator.                                          #
# # Please consider donation to help us maintain this project 🙏                 #
# # https://opencollective.com/openapi_generator/donate                          #
# ################################################################################
# Generated JavaScript client for query_openapi.json in /home/rico/Repos/json-to-openapi/GeneratedClient/snip721-collection/query_openapi
# snip721-collection/instantiate_openapi.json
# [main] INFO  o.o.codegen.DefaultGenerator - Generating with dryRun=false
# [main] INFO  o.o.c.ignore.CodegenIgnoreProcessor - Output directory (/local/GeneratedClient/snip721-collection/instantiate_openapi) does not exist, or is inaccessible. No file (.openapi-generator-ignore) will be evaluated.
# [main] INFO  o.o.codegen.DefaultGenerator - OpenAPI Generator: javascript (client)
# [main] INFO  o.o.codegen.DefaultGenerator - Generator 'javascript' is considered stable.
# [main] INFO  o.o.c.l.JavascriptClientCodegen - Environment variable JS_POST_PROCESS_FILE not defined so the JS code may not be properly formatted. To define it, try 'export JS_POST_PROCESS_FILE="/usr/local/bin/js-beautify -r -f"' (Linux/Mac)
# [main] INFO  o.o.c.l.JavascriptClientCodegen - NOTE: To enable file post-processing, 'enablePostProcessFile' must be set to `true` (--enable-post-process-file for CLI).
# [main] INFO  o.o.codegen.InlineModelResolver - Inline schema created as _execute_message_post_request. To have complete control of the model name, set the `title` field or use the modelNameMapping option (e.g. --model-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI) or inlineSchemaNameMapping option (--inline-schema-name-mappings _execute_message_post_request=NewModel,ModelA=NewModelA in CLI).
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/model/Coin.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/model/Coin.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/Coin.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/model/ExecuteMessagePostRequest.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/model/ExecuteMessagePostRequest.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/ExecuteMessagePostRequest.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/model/InstantiateConfig.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/model/InstantiateConfig.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/InstantiateConfig.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/model/PostInstantiateCallback.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/model/PostInstantiateCallback.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/PostInstantiateCallback.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/model/Royalty.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/model/Royalty.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/Royalty.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/model/RoyaltyInfo.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/model/RoyaltyInfo.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/RoyaltyInfo.md
# [main] WARN  o.o.codegen.DefaultCodegen - Empty operationId found for path: post /execute-message. Renamed to auto-generated operationId: execute_messagePost
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/api/DefaultApi.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/test/api/DefaultApi.spec.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/docs/DefaultApi.md
# [main] INFO  o.o.codegen.utils.URLPathUtils - 'host' (OAS 2.0) or 'servers' (OAS 3.0) not defined in the spec. Default to [http://localhost] for server URL [http://localhost/]
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/package.json
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/git_push.sh
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/README.md
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/mocha.opts
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/.travis.yml
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/.gitignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/index.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/src/ApiClient.js
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/.babelrc
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/.openapi-generator-ignore
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/.openapi-generator/VERSION
# [main] INFO  o.o.codegen.TemplateManager - writing file /local/GeneratedClient/snip721-collection/instantiate_openapi/.openapi-generator/FILES
# ################################################################################
# # Thanks for using OpenAPI Generator.                                          #
# # Please consider donation to help us maintain this project 🙏                 #
# # https://opencollective.com/openapi_generator/donate                          #
# ################################################################################
# Generated JavaScript client for instantiate_openapi.json in /home/rico/Repos/json-to-openapi/GeneratedClient/snip721-collection/instantiate_openapi
